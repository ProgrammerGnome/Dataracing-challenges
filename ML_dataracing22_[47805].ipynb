# %% [markdown]
# # Machine Learning beadandó feladata
# ## Dataracing 2022: exportforgalom előrejelzés
# Király Márk (AX83OL)

# %% [markdown]
# ### Importáljuk a szükséges modulokat.

# %%
import pandas as pd
import optuna
from optuna.samplers import TPESampler, GPSampler
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from imblearn.over_sampling import SMOTE
import numpy as np

# %% [markdown]
# ### Töltsük be az adatokat az alábbi sorrendben:
# #### 1. csv betöltése, 2. célváltozó beállítása, 3. tanító-teszt 0,6-0,4 felosztás
# Megj.: Ez a kommentek javítása miatt lett később lefuttatva, mint a többi cella => ha újból futtatnánk az összes cellát, akkor is hasonló MAE, MSE, R2 értékeket kapnánk.

# %%
# Adatok betöltése
df = pd.read_csv("https://raw.githubusercontent.com/karsarobert/Machine_Learning_2024/main/train.csv")

# Célváltozó és prediktorok beállítása
y = df['target_reg']
corr_col = ['arbevexp_2014', 'arbevexp_2015', 'arbevexp_2016', 'arbevert_2014', 'arbevert_2015', 'arbevert_2016']
X = df[corr_col]

# Adatok felosztása tanító és teszt halmazokra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %% [markdown]
# ### Végezzünk adatbővítést! (Zajjal és szintetikus adatok hozzáadásával is)
# #### Zajt adunk hozzá 0,1-es faktorral és 2-szer annyi szintetikus adatot gyártunk lineáris kombinációval, mint az eredeti tanítóhalmaz
# #### Ok: a tanítóhalmaz túl kicsi a 0,6-0,4-es felosztás miatt...

# %%
# Zaj hozzáadása
noise_factor = 0.1
X_train_noisy = X_train + noise_factor * np.random.randn(*X_train.shape)
X_test_noisy = X_test + noise_factor * np.random.randn(*X_test.shape)

# Szintetikus adatok generálása lineáris kombinációval
def generate_synthetic_data(X, y, num_samples):
    synthetic_X = []
    synthetic_y = []
    num_features = X.shape[1]
    
    for _ in range(num_samples):
        idx1, idx2 = np.random.choice(len(X), size=2, replace=False)
        alpha = np.random.rand()
        
        new_sample_X = alpha * X.iloc[idx1] + (1 - alpha) * X.iloc[idx2]
        new_sample_y = alpha * y.iloc[idx1] + (1 - alpha) * y.iloc[idx2]
        
        synthetic_X.append(new_sample_X)
        synthetic_y.append(new_sample_y)
    
    return pd.DataFrame(synthetic_X, columns=X.columns), pd.Series(synthetic_y)

# Generáljunk szintetikus adatokat a tanító halmazhoz
num_synthetic_samples = len(X_train) * 2  # 2-szer több szintetikus minta, mint az eredeti tanító halmaz
X_synthetic, y_synthetic = generate_synthetic_data(X_train, y_train, num_synthetic_samples)

# Kombináljuk az eredeti és szintetikus adatokat
X_train_augmented = pd.concat([X_train_noisy, X_synthetic])
y_train_augmented = pd.concat([y_train, y_synthetic])

# StandardScaler létrehozása és illesztése a tanító adatokra
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_augmented)
X_test_scaled = scaler.transform(X_test_noisy)

# Az újonnan zajosított és skálázott adatok ellenőrzése
print("X_train_scaled (augmented):", X_train_scaled[:5])
print("X_test_scaled:", X_test_scaled[:5])
# Out:
# X_train_scaled (augmented): [[-0.11330591 -0.10912084 -0.10768715 -0.00083785 -0.03849117 -0.1954651 ]
#  [-0.11330586 -0.10912077 -0.10768718 -0.23330005 -0.23690373 -0.23116736]
#  [-0.11330598 -0.10912076 -0.10768725 -0.099985   -0.11537316 -0.1158518 ]
#  [-0.11330588 -0.10912069 -0.10768722 -0.24661754 -0.24468327 -0.23788795]
#  [-0.11330599 -0.1091208  -0.10768711 -0.2435801  -0.2433832  -0.23787602]]
# X_test_scaled: [[-0.11330601 -0.10912084 -0.10768718 -0.23302266 -0.23560083 -0.23243503]
#  [-0.11330573 -0.10912071 -0.10768712  1.41922932  1.50132954  1.3707072 ]
#  [-0.11330592 -0.10912068 -0.10768724 -0.18437169 -0.18995129 -0.19806263]
#  [ 0.0255127   0.00175727 -0.00856693 -0.15829477 -0.17811143 -0.16801288]
#  [-0.11330582 -0.10912067 -0.10768712 -0.22912825 -0.22927216 -0.22774911]]

# %% [markdown]
# ## Építsünk modelt!
# ### Futtatáskor figyeljünk rá, hogy a MAE-t és a további jellemzőket az eredeti halmazon mérjük (y_test, y_pred).
# ### A modell a következőket használja:
# #### Random Forest regresszió,
# #### Optuna hiperparaméterkereső keretrendszer, ezen belűl a TPESampler fa alapú keresőalgoritmus

# %%
# Célfüggvény definiálása
def objective(trial):
    # Hiperparaméterek meghatározása
    n_estimators = trial.suggest_int('n_estimators', 10, 200) #(10,200)
    max_depth = trial.suggest_int('max_depth', 1, 20) #(1,20)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10) #(2,10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 4) #(1,4)
    
    # Random Forest modell létrehozása a megadott hiperparaméterekkel
    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42,
        n_jobs=-1
    )
    
    # Modell illesztése
    model.fit(X_train_scaled, y_train_augmented)
    
    # Előrejelzések készítése
    y_pred = model.predict(X_test_scaled)
    
    # MAE számolása
    mae = mean_absolute_error(y_test, y_pred)
    return mae

# "Tanulmány" létrehozása és futtatása
try:
    study = optuna.create_study(direction='minimize', sampler=TPESampler())
    study.optimize(objective, n_trials=100)  # , timeout=900) Tehát maximum 0,25 óráig fut - kikommentelve
except optuna.exceptions.TrialPruned as e:
    print("Optimization stopped:", e)

# Legjobb paraméterek kiíratása
print("Best hyperparameters: ", study.best_params)

# Legjobb modell létrehozása a legjobb paraméterekkel
best_params = study.best_params
best_model = RandomForestRegressor(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    random_state=42,  # Marad változatlan!
    n_jobs=-1  # Párhuzamosítás miatt kell (igaz csak CPU-n párhuzamosít...)
)

# Legjobb modell illesztése a teljes edzési adatokra
best_model.fit(X_train_scaled, y_train_augmented)

# Előrejelzések készítése a teszthalmazon
y_pred = best_model.predict(X_test_scaled)

# Hibametrikák kiértékelése és kiíratása
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print('Final Model Performance on Test Set:')
print('Mean Squared Error:', mse)
print('R-squared Score:', r2)
print('Mean Absolute Error:', mae)
# Out:
# [I 2024-06-02 10:04:59,566] A new study created in memory with name: no-name-e6fb5804-bbd8-40dc-af1c-43b637d8cfac
# [I 2024-06-02 10:05:04,680] Trial 0 finished with value: 48291.54805187346 and parameters: {'n_estimators': 90, 'max_depth': 19, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:06,017] Trial 1 finished with value: 66400.78307222281 and parameters: {'n_estimators': 93, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:14,728] Trial 2 finished with value: 48403.28179274183 and parameters: {'n_estimators': 196, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:16,377] Trial 3 finished with value: 49573.78651163134 and parameters: {'n_estimators': 45, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:20,557] Trial 4 finished with value: 49340.75176287043 and parameters: {'n_estimators': 79, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:21,860] Trial 5 finished with value: 155875.89454641475 and parameters: {'n_estimators': 155, 'max_depth': 2, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:22,748] Trial 6 finished with value: 54657.17157648909 and parameters: {'n_estimators': 40, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:26,225] Trial 7 finished with value: 52679.54202868375 and parameters: {'n_estimators': 147, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:28,557] Trial 8 finished with value: 49557.08959904763 and parameters: {'n_estimators': 56, 'max_depth': 11, 'min_samples_split': 2, 'min_samples_leaf': 1}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:33,993] Trial 9 finished with value: 48413.66144326674 and parameters: {'n_estimators': 120, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:35,375] Trial 10 finished with value: 49183.397123926545 and parameters: {'n_estimators': 18, 'max_depth': 20, 'min_samples_split': 2, 'min_samples_leaf': 3}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:43,234] Trial 11 finished with value: 48399.142574092984 and parameters: {'n_estimators': 119, 'max_depth': 19, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:05:51,853] Trial 12 finished with value: 48397.21202230575 and parameters: {'n_estimators': 121, 'max_depth': 20, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:06:00,536] Trial 13 finished with value: 48956.370442332074 and parameters: {'n_estimators': 150, 'max_depth': 16, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 0 with value: 48291.54805187346.
# [I 2024-06-02 10:06:05,272] Trial 14 finished with value: 48209.27019118233 and parameters: {'n_estimators': 75, 'max_depth': 17, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:09,281] Trial 15 finished with value: 49219.393684329436 and parameters: {'n_estimators': 72, 'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:12,270] Trial 16 finished with value: 49602.38455191795 and parameters: {'n_estimators': 95, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:13,104] Trial 17 finished with value: 49612.070142993936 and parameters: {'n_estimators': 12, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:16,820] Trial 18 finished with value: 48978.25615412419 and parameters: {'n_estimators': 72, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:20,389] Trial 19 finished with value: 49707.21687394822 and parameters: {'n_estimators': 55, 'max_depth': 18, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:25,982] Trial 20 finished with value: 48291.01623725034 and parameters: {'n_estimators': 105, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:31,565] Trial 21 finished with value: 48268.783465477536 and parameters: {'n_estimators': 104, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:36,976] Trial 22 finished with value: 48280.27041029754 and parameters: {'n_estimators': 107, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:41,117] Trial 23 finished with value: 48441.41494107929 and parameters: {'n_estimators': 124, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:47,908] Trial 24 finished with value: 48886.65676899756 and parameters: {'n_estimators': 136, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:53,913] Trial 25 finished with value: 48646.41283960147 and parameters: {'n_estimators': 170, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:06:59,565] Trial 26 finished with value: 49004.44197072575 and parameters: {'n_estimators': 105, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 14 with value: 48209.27019118233.
# [I 2024-06-02 10:07:03,194] Trial 27 finished with value: 48097.15674970127 and parameters: {'n_estimators': 81, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:04,625] Trial 28 finished with value: 49269.22328942378 and parameters: {'n_estimators': 30, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:09,795] Trial 29 finished with value: 48255.89902255716 and parameters: {'n_estimators': 80, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:14,027] Trial 30 finished with value: 49480.86630998854 and parameters: {'n_estimators': 63, 'max_depth': 18, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:19,541] Trial 31 finished with value: 48178.78263997711 and parameters: {'n_estimators': 83, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:24,949] Trial 32 finished with value: 48211.99999422612 and parameters: {'n_estimators': 84, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:30,498] Trial 33 finished with value: 48173.347706100845 and parameters: {'n_estimators': 88, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:36,088] Trial 34 finished with value: 48254.29028578892 and parameters: {'n_estimators': 92, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:40,906] Trial 35 finished with value: 48300.82309437741 and parameters: {'n_estimators': 68, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:43,655] Trial 36 finished with value: 48523.40176032767 and parameters: {'n_estimators': 44, 'max_depth': 17, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:48,427] Trial 37 finished with value: 49117.66097376966 and parameters: {'n_estimators': 89, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:52,217] Trial 38 finished with value: 48596.333412254964 and parameters: {'n_estimators': 56, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:55,821] Trial 39 finished with value: 49239.6589106721 and parameters: {'n_estimators': 79, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:07:56,708] Trial 40 finished with value: 93955.68703656537 and parameters: {'n_estimators': 63, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:08:02,555] Trial 41 finished with value: 48234.27106042307 and parameters: {'n_estimators': 86, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:08:08,187] Trial 42 finished with value: 48395.152038361164 and parameters: {'n_estimators': 95, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 27 with value: 48097.15674970127.
# [I 2024-06-02 10:08:13,530] Trial 43 finished with value: 48027.551854636644 and parameters: {'n_estimators': 86, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:08:17,995] Trial 44 finished with value: 48190.41000085851 and parameters: {'n_estimators': 76, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:08:22,920] Trial 45 finished with value: 48081.26202017152 and parameters: {'n_estimators': 99, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:08:27,139] Trial 46 finished with value: 48525.944546762934 and parameters: {'n_estimators': 110, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:08:32,033] Trial 47 finished with value: 48063.717198679646 and parameters: {'n_estimators': 98, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:08:37,994] Trial 48 finished with value: 48285.791148482305 and parameters: {'n_estimators': 130, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:08:42,027] Trial 49 finished with value: 48609.36084379965 and parameters: {'n_estimators': 100, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:08:45,315] Trial 50 finished with value: 49842.66847672902 and parameters: {'n_estimators': 116, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:08:50,200] Trial 51 finished with value: 48072.793013937 and parameters: {'n_estimators': 97, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:08:55,218] Trial 52 finished with value: 48114.35462781349 and parameters: {'n_estimators': 98, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:08:59,805] Trial 53 finished with value: 48092.02721435466 and parameters: {'n_estimators': 95, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:09:05,046] Trial 54 finished with value: 48207.56924303906 and parameters: {'n_estimators': 113, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:09:08,892] Trial 55 finished with value: 48174.22811036835 and parameters: {'n_estimators': 98, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:09:14,981] Trial 56 finished with value: 48266.26313716036 and parameters: {'n_estimators': 128, 'max_depth': 13, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:09:20,720] Trial 57 finished with value: 48594.97438065109 and parameters: {'n_estimators': 138, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:09:28,575] Trial 58 finished with value: 49275.600711118626 and parameters: {'n_estimators': 183, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:09:30,871] Trial 59 finished with value: 48206.15401928237 and parameters: {'n_estimators': 67, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:09:36,996] Trial 60 finished with value: 48323.27525803789 and parameters: {'n_estimators': 113, 'max_depth': 15, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:09:41,873] Trial 61 finished with value: 48044.92528103666 and parameters: {'n_estimators': 99, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:09:46,297] Trial 62 finished with value: 48101.091994382696 and parameters: {'n_estimators': 91, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:09:50,798] Trial 63 finished with value: 48272.24983523536 and parameters: {'n_estimators': 102, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:09:55,974] Trial 64 finished with value: 48072.26807727314 and parameters: {'n_estimators': 107, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:10:01,870] Trial 65 finished with value: 48144.86591021788 and parameters: {'n_estimators': 121, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:10:07,521] Trial 66 finished with value: 48269.44378637933 and parameters: {'n_estimators': 108, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:10:10,944] Trial 67 finished with value: 48236.60599690652 and parameters: {'n_estimators': 94, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:10:16,189] Trial 68 finished with value: 48798.95331159888 and parameters: {'n_estimators': 105, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:10:22,615] Trial 69 finished with value: 49198.9224676469 and parameters: {'n_estimators': 118, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:10:29,583] Trial 70 finished with value: 48407.25189915429 and parameters: {'n_estimators': 126, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 43 with value: 48027.551854636644.
# [I 2024-06-02 10:10:33,437] Trial 71 finished with value: 48020.41821251471 and parameters: {'n_estimators': 82, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 71 with value: 48020.41821251471.
# [I 2024-06-02 10:10:37,389] Trial 72 finished with value: 48122.04907306892 and parameters: {'n_estimators': 88, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 71 with value: 48020.41821251471.
# [I 2024-06-02 10:10:42,178] Trial 73 finished with value: 48063.717198679646 and parameters: {'n_estimators': 98, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 71 with value: 48020.41821251471.
# [I 2024-06-02 10:10:45,302] Trial 74 finished with value: 48174.69304406574 and parameters: {'n_estimators': 75, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 71 with value: 48020.41821251471.
# [I 2024-06-02 10:10:50,381] Trial 75 finished with value: 48291.408430117604 and parameters: {'n_estimators': 100, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 71 with value: 48020.41821251471.
# [I 2024-06-02 10:10:55,377] Trial 76 finished with value: 48174.32147108333 and parameters: {'n_estimators': 112, 'max_depth': 12, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 71 with value: 48020.41821251471.
# [I 2024-06-02 10:10:59,408] Trial 77 finished with value: 47984.62083699831 and parameters: {'n_estimators': 83, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 77 with value: 47984.62083699831.
# [I 2024-06-02 10:11:02,242] Trial 78 finished with value: 48443.420532484524 and parameters: {'n_estimators': 50, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 77 with value: 47984.62083699831.
# [I 2024-06-02 10:11:02,700] Trial 79 finished with value: 268318.20854907867 and parameters: {'n_estimators': 82, 'max_depth': 1, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 77 with value: 47984.62083699831.
# [I 2024-06-02 10:11:04,291] Trial 80 finished with value: 55367.25558292392 and parameters: {'n_estimators': 72, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 77 with value: 47984.62083699831.
# [I 2024-06-02 10:11:08,788] Trial 81 finished with value: 48022.00558743358 and parameters: {'n_estimators': 86, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 77 with value: 47984.62083699831.
# [I 2024-06-02 10:11:13,009] Trial 82 finished with value: 47994.28314702402 and parameters: {'n_estimators': 84, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 77 with value: 47984.62083699831.
# [I 2024-06-02 10:11:17,749] Trial 83 finished with value: 48018.42688256932 and parameters: {'n_estimators': 85, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 77 with value: 47984.62083699831.
# [I 2024-06-02 10:11:22,266] Trial 84 finished with value: 47859.814512499186 and parameters: {'n_estimators': 84, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 84 with value: 47859.814512499186.
# [I 2024-06-02 10:11:25,769] Trial 85 finished with value: 48085.67801132218 and parameters: {'n_estimators': 63, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 84 with value: 47859.814512499186.
# [I 2024-06-02 10:11:30,242] Trial 86 finished with value: 48587.680544810726 and parameters: {'n_estimators': 77, 'max_depth': 16, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 84 with value: 47859.814512499186.
# [I 2024-06-02 10:11:34,859] Trial 87 finished with value: 47859.814512499186 and parameters: {'n_estimators': 84, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 84 with value: 47859.814512499186.
# [I 2024-06-02 10:11:38,834] Trial 88 finished with value: 48190.90263187993 and parameters: {'n_estimators': 68, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 84 with value: 47859.814512499186.
# [I 2024-06-02 10:11:43,396] Trial 89 finished with value: 49127.3840513602 and parameters: {'n_estimators': 84, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 84 with value: 47859.814512499186.
# [I 2024-06-02 10:11:48,000] Trial 90 finished with value: 47805.93572784237 and parameters: {'n_estimators': 87, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 90 with value: 47805.93572784237.
# [I 2024-06-02 10:11:52,738] Trial 91 finished with value: 47950.228757171135 and parameters: {'n_estimators': 91, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 90 with value: 47805.93572784237.
# [I 2024-06-02 10:11:57,978] Trial 92 finished with value: 47887.32945051897 and parameters: {'n_estimators': 87, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 90 with value: 47805.93572784237.
# [I 2024-06-02 10:12:01,715] Trial 93 finished with value: 48005.42233149208 and parameters: {'n_estimators': 72, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 90 with value: 47805.93572784237.
# [I 2024-06-02 10:12:06,047] Trial 94 finished with value: 48028.16726971436 and parameters: {'n_estimators': 79, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 90 with value: 47805.93572784237.
# [I 2024-06-02 10:12:09,829] Trial 95 finished with value: 48005.42233149208 and parameters: {'n_estimators': 72, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 90 with value: 47805.93572784237.
# [I 2024-06-02 10:12:13,780] Trial 96 finished with value: 48053.805917357764 and parameters: {'n_estimators': 73, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 90 with value: 47805.93572784237.
# [I 2024-06-02 10:12:17,443] Trial 97 finished with value: 48200.44055268153 and parameters: {'n_estimators': 60, 'max_depth': 16, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 90 with value: 47805.93572784237.
# [I 2024-06-02 10:12:22,050] Trial 98 finished with value: 48406.46772578518 and parameters: {'n_estimators': 69, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 90 with value: 47805.93572784237.
# [I 2024-06-02 10:12:26,845] Trial 99 finished with value: 47970.01308483345 and parameters: {'n_estimators': 90, 'max_depth': 15, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 90 with value: 47805.93572784237.
# Best hyperparameters:  {'n_estimators': 87, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 2}
# Final Model Performance on Test Set:
# Mean Squared Error: 178867436035.9132
# R-squared Score: 0.9708414213562483
# Mean Absolute Error: 47805.93572784237

# %% [markdown]
# Best hyperparameters:  {'n_estimators': 87, 'max_depth': 14, 'min_samples_split': 8, 'min_samples_leaf': 2}
# Final Model Performance on Test Set:
# Mean Squared Error: 178867436035.9132
# R-squared Score: 0.9708414213562483
# Mean Absolute Error: 47805.93572784237

# %% [markdown]
# ## MAE: 47805
