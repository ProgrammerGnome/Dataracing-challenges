# %% [markdown]
# # Machine Learning beadandó feladata
# ## Dataracing 2022: exportforgalom előrejelzés
# Király Márk (AX83OL)

# %% [markdown]
# ### Importáljuk a szükséges modulokat.

# %%
import pandas as pd
import optuna
from optuna.samplers import TPESampler, GPSampler
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from imblearn.over_sampling import SMOTE
import numpy as np

# %% [markdown]
# ### Töltsük be az adatokat az alábbi sorrendben:
# #### 1. csv betöltése, 2. célváltozó beállítása, 3. tanító-teszt 0,6-0,4 felosztás
# Megj.: Ez a kommentek javítása miatt lett később lefuttatva, mint a többi cella => ha újból futtatnánk az összes cellát, akkor is hasonló MAE, MSE, R2 értékeket kapnánk.

# %%
# Adatok betöltése
df = pd.read_csv("https://raw.githubusercontent.com/karsarobert/Machine_Learning_2024/main/train.csv")

# Célváltozó és prediktorok beállítása
y = df['target_reg']
corr_col = ['arbevexp_2014', 'arbevexp_2015', 'arbevexp_2016', 'arbevert_2014', 'arbevert_2015', 'arbevert_2016', 'ranyag_2014', 'ranyag_2015', 'ranyag_2016', 'rszem_2016']
X = df[corr_col]

# Adatok felosztása tanító és teszt halmazokra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42)

# %% [markdown]
# ### Végezzünk adatbővítést! (Zajjal és szintetikus adatok hozzáadásával is)
# #### Zajt adunk hozzá 0,1-es faktorral és 2-szer annyi szintetikus adatot gyártunk lineáris kombinációval, mint az eredeti tanítóhalmaz
# #### Ok: a tanítóhalmaz túl kicsi a 0,6-0,4-es felosztás miatt...

# %%
# Zaj hozzáadása
noise_factor = 0.1
X_train_noisy = X_train + noise_factor * np.random.randn(*X_train.shape)
X_test_noisy = X_test + noise_factor * np.random.randn(*X_test.shape)

# Szintetikus adatok generálása lineáris kombinációval
def generate_synthetic_data(X, y, num_samples):
    synthetic_X = []
    synthetic_y = []
    num_features = X.shape[1]
    
    for _ in range(num_samples):
        idx1, idx2 = np.random.choice(len(X), size=2, replace=False)
        alpha = np.random.rand()
        
        new_sample_X = alpha * X.iloc[idx1] + (1 - alpha) * X.iloc[idx2]
        new_sample_y = alpha * y.iloc[idx1] + (1 - alpha) * y.iloc[idx2]
        
        synthetic_X.append(new_sample_X)
        synthetic_y.append(new_sample_y)
    
    return pd.DataFrame(synthetic_X, columns=X.columns), pd.Series(synthetic_y)

# Generáljunk szintetikus adatokat a tanító halmazhoz
num_synthetic_samples = len(X_train) * 2  # 2-szer több szintetikus minta, mint az eredeti tanító halmaz
X_synthetic, y_synthetic = generate_synthetic_data(X_train, y_train, num_synthetic_samples)

# Kombináljuk az eredeti és szintetikus adatokat
X_train_augmented = pd.concat([X_train_noisy, X_synthetic])
y_train_augmented = pd.concat([y_train, y_synthetic])

# StandardScaler létrehozása és illesztése a tanító adatokra
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_augmented)
X_test_scaled = scaler.transform(X_test_noisy)

# Az újonnan zajosított és skálázott adatok ellenőrzése
print("X_train_scaled (augmented):", X_train_scaled[:5])
print("X_test_scaled:", X_test_scaled[:5])
# Out:
# X_train_scaled (augmented): [[-0.11353001 -0.11254884 -0.11248401 -0.00609474 -0.04272862 -0.19992831
#    0.03284351 -0.03458288 -0.17977939 -0.17114873]
#  [-0.11352997 -0.11254879 -0.11248395 -0.23174224 -0.23885215 -0.23578411
#   -0.21773128 -0.22773672 -0.22175522 -0.18010741]
#  [-0.11352999 -0.11254878 -0.1124841  -0.10233538 -0.1187236  -0.11997266
#   -0.06456833 -0.07401679 -0.0566597  -0.16567638]
#  [-0.11353006 -0.11254891 -0.11248407 -0.24466937 -0.24654198 -0.24253352
#   -0.22689106 -0.23864735 -0.23098685 -0.18468017]
#  [-0.11352995 -0.11254887 -0.11248399 -0.24172092 -0.24525681 -0.24252162
#   -0.22748765 -0.23790381 -0.22894936 -0.17552071]]
# X_test_scaled: [[-0.11353001 -0.11254883 -0.11248402 -0.23147299 -0.23756431 -0.23705724
#   -0.21536593 -0.22864936 -0.2222903  -0.17987296]
#  [-0.11352984 -0.11254879 -0.11248406  1.37234286  1.4793277   1.37297924
#    0.90920258  1.09402199  0.95387358  2.63551017]
#  [-0.11352989 -0.11254887 -0.11248408 -0.18424826 -0.19244134 -0.20253702
#   -0.20610112 -0.21620665 -0.20628264 -0.11641338]
#  [ 0.01397841 -0.0061152  -0.01560121 -0.15893578 -0.18073815 -0.17235805
#   -0.16975383 -0.18908789 -0.17741724 -0.10651468]
#  [-0.1135299  -0.11254888 -0.11248401 -0.22769272 -0.2313086  -0.23235118
#   -0.209898   -0.22005403 -0.21571304 -0.18286923]]

# %% [markdown]
# ## Építsünk modelt!
# ### Futtatáskor figyeljünk rá, hogy a MAE-t és a további jellemzőket az eredeti halmazon mérjük (y_test, y_pred).
# ### A modell a következőket használja:
# #### Random Forest regresszió,
# #### Optuna hiperparaméterkereső keretrendszer, ezen belűl a TPESampler fa alapú keresőalgoritmus

# %%
# Célfüggvény definiálása
def objective(trial):
    # Hiperparaméterek meghatározása
    n_estimators = trial.suggest_int('n_estimators', 10, 200) #(10,200)
    max_depth = trial.suggest_int('max_depth', 1, 20) #(1,20)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10) #(2,10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 4) #(1,4)
    
    # Random Forest modell létrehozása a megadott hiperparaméterekkel
    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42,
        n_jobs=-1
    )
    
    # Modell illesztése
    model.fit(X_train_scaled, y_train_augmented)
    
    # Előrejelzések készítése
    y_pred = model.predict(X_test_scaled)
    
    # MAE számolása
    mae = mean_absolute_error(y_test, y_pred)
    return mae

# "Tanulmány" létrehozása és futtatása
try:
    study = optuna.create_study(direction='minimize', sampler=TPESampler())
    study.optimize(objective, n_trials=100)  # , timeout=900) Tehát maximum 0,25 óráig fut - kikommentelve
except optuna.exceptions.TrialPruned as e:
    print("Optimization stopped:", e)

# Legjobb paraméterek kiíratása
print("Best hyperparameters: ", study.best_params)

# Legjobb modell létrehozása a legjobb paraméterekkel
best_params = study.best_params
best_model = RandomForestRegressor(
    n_estimators=best_params['n_estimators'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    random_state=42,  # Marad változatlan!
    n_jobs=-1  # Párhuzamosítás miatt kell (igaz csak CPU-n párhuzamosít...)
)

# Legjobb modell illesztése a teljes edzési adatokra
best_model.fit(X_train_scaled, y_train_augmented)

# Előrejelzések készítése a teszthalmazon
y_pred = best_model.predict(X_test_scaled)

# Hibametrikák kiértékelése és kiíratása
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print('Final Model Performance on Test Set:')
print('Mean Squared Error:', mse)
print('R-squared Score:', r2)
print('Mean Absolute Error:', mae)
# Out:
# [I 2024-05-27 14:20:01,547] A new study created in memory with name: no-name-d5efb255-1b3c-4b10-9d3e-84a3dc49f2b5
# [I 2024-05-27 14:20:02,453] Trial 0 finished with value: 52624.378209158735 and parameters: {'n_estimators': 15, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 0 with value: 52624.378209158735.
# [I 2024-05-27 14:20:03,140] Trial 1 finished with value: 275591.2658043612 and parameters: {'n_estimators': 89, 'max_depth': 1, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 0 with value: 52624.378209158735.
# [I 2024-05-27 14:20:03,404] Trial 2 finished with value: 275286.1840526459 and parameters: {'n_estimators': 31, 'max_depth': 1, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 0 with value: 52624.378209158735.
# [I 2024-05-27 14:20:16,198] Trial 3 finished with value: 50732.13060849724 and parameters: {'n_estimators': 193, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 3 with value: 50732.13060849724.
# [I 2024-05-27 14:20:22,922] Trial 4 finished with value: 52814.04850346206 and parameters: {'n_estimators': 137, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 3 with value: 50732.13060849724.
# [I 2024-05-27 14:20:24,981] Trial 5 finished with value: 51228.03661505747 and parameters: {'n_estimators': 29, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 3 with value: 50732.13060849724.
# [I 2024-05-27 14:20:32,463] Trial 6 finished with value: 49934.28884701342 and parameters: {'n_estimators': 115, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 2}. Best is trial 6 with value: 49934.28884701342.
# [I 2024-05-27 14:20:34,179] Trial 7 finished with value: 50778.49734184126 and parameters: {'n_estimators': 20, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 6 with value: 49934.28884701342.
# [I 2024-05-27 14:20:35,513] Trial 8 finished with value: 50756.02194107995 and parameters: {'n_estimators': 11, 'max_depth': 16, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 6 with value: 49934.28884701342.
# [I 2024-05-27 14:20:39,639] Trial 9 finished with value: 60024.74807610806 and parameters: {'n_estimators': 110, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 6 with value: 49934.28884701342.
# [I 2024-05-27 14:20:58,745] Trial 10 finished with value: 50020.91645819268 and parameters: {'n_estimators': 162, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 6 with value: 49934.28884701342.
# [I 2024-05-27 14:21:19,584] Trial 11 finished with value: 49970.81320288862 and parameters: {'n_estimators': 166, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 6 with value: 49934.28884701342.
# [I 2024-05-27 14:21:27,839] Trial 12 finished with value: 49823.31144774942 and parameters: {'n_estimators': 81, 'max_depth': 14, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 12 with value: 49823.31144774942.
# [I 2024-05-27 14:21:34,947] Trial 13 finished with value: 49865.97571546762 and parameters: {'n_estimators': 74, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 12 with value: 49823.31144774942.
# [I 2024-05-27 14:21:41,207] Trial 14 finished with value: 51000.826468274565 and parameters: {'n_estimators': 63, 'max_depth': 14, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 12 with value: 49823.31144774942.
# [I 2024-05-27 14:21:47,617] Trial 15 finished with value: 49745.6839994052 and parameters: {'n_estimators': 68, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 15 with value: 49745.6839994052.
# [I 2024-05-27 14:21:53,227] Trial 16 finished with value: 50040.498525689276 and parameters: {'n_estimators': 55, 'max_depth': 15, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 15 with value: 49745.6839994052.
# [I 2024-05-27 14:22:01,069] Trial 17 finished with value: 51087.71714733484 and parameters: {'n_estimators': 83, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 15 with value: 49745.6839994052.
# [I 2024-05-27 14:22:07,097] Trial 18 finished with value: 49704.78943670931 and parameters: {'n_estimators': 47, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 18 with value: 49704.78943670931.
# [I 2024-05-27 14:22:13,854] Trial 19 finished with value: 51131.662342237774 and parameters: {'n_estimators': 49, 'max_depth': 17, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 18 with value: 49704.78943670931.
# [I 2024-05-27 14:22:19,345] Trial 20 finished with value: 50752.58758654397 and parameters: {'n_estimators': 37, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 18 with value: 49704.78943670931.
# [I 2024-05-27 14:22:29,153] Trial 21 finished with value: 49849.79581468079 and parameters: {'n_estimators': 92, 'max_depth': 14, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 18 with value: 49704.78943670931.
# [I 2024-05-27 14:22:38,002] Trial 22 finished with value: 49926.14127293718 and parameters: {'n_estimators': 68, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 18 with value: 49704.78943670931.
# [I 2024-05-27 14:22:43,282] Trial 23 finished with value: 49925.69824695571 and parameters: {'n_estimators': 47, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 18 with value: 49704.78943670931.
# [I 2024-05-27 14:22:52,200] Trial 24 finished with value: 49650.492737169705 and parameters: {'n_estimators': 101, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 24 with value: 49650.492737169705.
# [I 2024-05-27 14:23:02,048] Trial 25 finished with value: 49019.27652498846 and parameters: {'n_estimators': 130, 'max_depth': 11, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:23:08,033] Trial 26 finished with value: 55635.005995974236 and parameters: {'n_estimators': 135, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:23:11,797] Trial 27 finished with value: 72218.45702516846 and parameters: {'n_estimators': 129, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:23:23,571] Trial 28 finished with value: 49313.00540189609 and parameters: {'n_estimators': 155, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:23:32,582] Trial 29 finished with value: 50771.020022078774 and parameters: {'n_estimators': 159, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:23:43,263] Trial 30 finished with value: 49537.942946832525 and parameters: {'n_estimators': 150, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:23:55,064] Trial 31 finished with value: 49329.343349554736 and parameters: {'n_estimators': 149, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:24:06,008] Trial 32 finished with value: 49481.56387605235 and parameters: {'n_estimators': 148, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:24:20,582] Trial 33 finished with value: 49345.15342168704 and parameters: {'n_estimators': 182, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:24:36,046] Trial 34 finished with value: 49345.15342168705 and parameters: {'n_estimators': 182, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:24:47,516] Trial 35 finished with value: 50776.80938900432 and parameters: {'n_estimators': 178, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:24:59,089] Trial 36 finished with value: 49063.37799782373 and parameters: {'n_estimators': 121, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:25:10,353] Trial 37 finished with value: 49453.230082699476 and parameters: {'n_estimators': 123, 'max_depth': 12, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:25:19,718] Trial 38 finished with value: 49622.924267088885 and parameters: {'n_estimators': 144, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:25:21,646] Trial 39 finished with value: 157996.6504428497 and parameters: {'n_estimators': 117, 'max_depth': 2, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:25:27,574] Trial 40 finished with value: 50824.44533751587 and parameters: {'n_estimators': 100, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:25:41,776] Trial 41 finished with value: 49432.34927319146 and parameters: {'n_estimators': 177, 'max_depth': 11, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:25:58,683] Trial 42 finished with value: 49557.83344514739 and parameters: {'n_estimators': 189, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:26:14,424] Trial 43 finished with value: 49376.31682311424 and parameters: {'n_estimators': 199, 'max_depth': 11, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:26:25,851] Trial 44 finished with value: 49683.19320224615 and parameters: {'n_estimators': 168, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:26:35,759] Trial 45 finished with value: 49845.57913067064 and parameters: {'n_estimators': 138, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:26:48,807] Trial 46 finished with value: 49961.305888749805 and parameters: {'n_estimators': 156, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:26:55,094] Trial 47 finished with value: 52311.746915808566 and parameters: {'n_estimators': 124, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:27:09,469] Trial 48 finished with value: 49476.19816642376 and parameters: {'n_estimators': 139, 'max_depth': 15, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:27:19,649] Trial 49 finished with value: 49058.61445220227 and parameters: {'n_estimators': 109, 'max_depth': 13, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:27:30,189] Trial 50 finished with value: 49862.1306996128 and parameters: {'n_estimators': 112, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:27:44,433] Trial 51 finished with value: 49501.040239026814 and parameters: {'n_estimators': 170, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:27:53,610] Trial 52 finished with value: 49329.39140967557 and parameters: {'n_estimators': 131, 'max_depth': 10, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:28:02,667] Trial 53 finished with value: 49396.59907568833 and parameters: {'n_estimators': 130, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:28:13,792] Trial 54 finished with value: 49141.533427816714 and parameters: {'n_estimators': 120, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:28:24,833] Trial 55 finished with value: 49118.6682778873 and parameters: {'n_estimators': 118, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:28:33,759] Trial 56 finished with value: 49214.06208994993 and parameters: {'n_estimators': 93, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:28:44,537] Trial 57 finished with value: 50023.24809203287 and parameters: {'n_estimators': 105, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:28:53,779] Trial 58 finished with value: 49264.1278943729 and parameters: {'n_estimators': 91, 'max_depth': 14, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 25 with value: 49019.27652498846.
# [I 2024-05-27 14:29:06,841] Trial 59 finished with value: 48955.15009596134 and parameters: {'n_estimators': 118, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:29:20,694] Trial 60 finished with value: 49481.45293712391 and parameters: {'n_estimators': 119, 'max_depth': 17, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:29:32,844] Trial 61 finished with value: 49100.84137710925 and parameters: {'n_estimators': 110, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:29:45,135] Trial 62 finished with value: 49110.75578236871 and parameters: {'n_estimators': 109, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:29:57,388] Trial 63 finished with value: 49143.72000555312 and parameters: {'n_estimators': 108, 'max_depth': 16, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:30:10,174] Trial 64 finished with value: 49099.98068099624 and parameters: {'n_estimators': 101, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:30:19,901] Trial 65 finished with value: 49411.2266177578 and parameters: {'n_estimators': 82, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:30:33,012] Trial 66 finished with value: 49258.30390173833 and parameters: {'n_estimators': 99, 'max_depth': 20, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:30:46,285] Trial 67 finished with value: 49096.50612363613 and parameters: {'n_estimators': 112, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:30:55,987] Trial 68 finished with value: 49974.012575944194 and parameters: {'n_estimators': 76, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:31:07,836] Trial 69 finished with value: 49316.17252839899 and parameters: {'n_estimators': 96, 'max_depth': 19, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:31:20,931] Trial 70 finished with value: 49082.34730673311 and parameters: {'n_estimators': 105, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:31:31,774] Trial 71 finished with value: 49150.151863712046 and parameters: {'n_estimators': 86, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:31:45,327] Trial 72 finished with value: 49041.16597349929 and parameters: {'n_estimators': 113, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:32:00,433] Trial 73 finished with value: 49213.59575154198 and parameters: {'n_estimators': 125, 'max_depth': 18, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:32:13,066] Trial 74 finished with value: 49333.248276689745 and parameters: {'n_estimators': 104, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:32:27,593] Trial 75 finished with value: 49809.305821500544 and parameters: {'n_estimators': 113, 'max_depth': 19, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:32:42,453] Trial 76 finished with value: 49283.54778553464 and parameters: {'n_estimators': 128, 'max_depth': 17, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:32:55,446] Trial 77 finished with value: 49134.14877002867 and parameters: {'n_estimators': 98, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:33:12,091] Trial 78 finished with value: 49392.30057523201 and parameters: {'n_estimators': 134, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:33:25,716] Trial 79 finished with value: 49342.321420673376 and parameters: {'n_estimators': 114, 'max_depth': 18, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:33:36,554] Trial 80 finished with value: 49774.99636790923 and parameters: {'n_estimators': 104, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 2}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:33:51,044] Trial 81 finished with value: 49042.06788857336 and parameters: {'n_estimators': 110, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:34:07,484] Trial 82 finished with value: 49108.29689006594 and parameters: {'n_estimators': 122, 'max_depth': 20, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:34:18,753] Trial 83 finished with value: 49273.59774694989 and parameters: {'n_estimators': 88, 'max_depth': 19, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:34:32,027] Trial 84 finished with value: 49404.47791120021 and parameters: {'n_estimators': 114, 'max_depth': 17, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:34:41,782] Trial 85 finished with value: 48960.6031043851 and parameters: {'n_estimators': 106, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:34:54,461] Trial 86 finished with value: 50868.87892755099 and parameters: {'n_estimators': 144, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 59 with value: 48955.15009596134.
# [I 2024-05-27 14:35:05,254] Trial 87 finished with value: 48889.61616231008 and parameters: {'n_estimators': 125, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:35:16,379] Trial 88 finished with value: 48912.270050583764 and parameters: {'n_estimators': 127, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:35:27,017] Trial 89 finished with value: 48928.99987728741 and parameters: {'n_estimators': 126, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:35:38,352] Trial 90 finished with value: 48912.270050583764 and parameters: {'n_estimators': 127, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:35:50,505] Trial 91 finished with value: 48980.836950103745 and parameters: {'n_estimators': 134, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:36:02,514] Trial 92 finished with value: 49019.1004565648 and parameters: {'n_estimators': 143, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:36:14,168] Trial 93 finished with value: 48998.5058599087 and parameters: {'n_estimators': 142, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:36:26,607] Trial 94 finished with value: 48958.49876073326 and parameters: {'n_estimators': 142, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:36:38,930] Trial 95 finished with value: 48948.12349550113 and parameters: {'n_estimators': 145, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:36:52,307] Trial 96 finished with value: 48964.412601576085 and parameters: {'n_estimators': 151, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:37:04,308] Trial 97 finished with value: 48980.836950103745 and parameters: {'n_estimators': 134, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:37:18,304] Trial 98 finished with value: 48964.41260157609 and parameters: {'n_estimators': 151, 'max_depth': 13, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# [I 2024-05-27 14:37:33,822] Trial 99 finished with value: 49047.22367378848 and parameters: {'n_estimators': 154, 'max_depth': 15, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 87 with value: 48889.61616231008.
# Best hyperparameters:  {'n_estimators': 125, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1}
# Final Model Performance on Test Set:
# Mean Squared Error: 185225496112.8629
# R-squared Score: 0.9698049442932114
# Mean Absolute Error: 48889.61616231008

# %% [markdown]
# Best hyperparameters:  {'n_estimators': 125, 'max_depth': 12, 'min_samples_split': 7, 'min_samples_leaf': 1}
# Final Model Performance on Test Set:
# Mean Squared Error: 185225496112.8629
# R-squared Score: 0.9698049442932114
# Mean Absolute Error: 48889.61616231008

# %% [markdown]
# ## MAE: 48889
